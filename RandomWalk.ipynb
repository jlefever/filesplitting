# %%
import sqlite3

import numpy as np
import pandas as pd
from numpy import linalg

import db

# %%
Df = pd.DataFrame

# %%
DB_FILE = "android-base.db"
LEAD_REF = "refs/tags/android-13.0.0_r24"
TARGET_FILE = "core/java/android/view/View.java"
TARGET_ID = 102495 # The id of the top-level class of the target file

# %%
CON = sqlite3.connect(DB_FILE)

# %%
db.create_temp_tables(CON)
deps_df = db.fetch_internal_deps(CON, TARGET_ID)
deps_df = deps_df[(deps_df["kind"] == "Call") | (deps_df["kind"] == "Use")]
entities_df = db.fetch_children_of(CON, LEAD_REF, TARGET_ID)
entity_ids = list(entities_df.index)

# %%
def to_entity_id(ix: int) -> int:
    return entity_ids[ix]

def to_entity_ix(id: int) -> int:
    return entity_ids.index(id)

# %%
def create_sym_mat(n_entities, deps_df: Df) -> np.ndarray:
    arr = np.zeros((n_entities, n_entities))
    for _, row in deps_df.iterrows():
        src_ix = to_entity_ix(row["src_id"])
        tgt_ix = to_entity_ix(row["tgt_id"])
        arr[(src_ix, tgt_ix)] = 1.0
        arr[(tgt_ix, src_ix)] = 1.0
    return arr

# %%
entities_df
# Out:
#         parent_id                                  name    kind  start_row  \
# id
# 102496     102495                                   DBG   field        841
# 102497     102495                            DEBUG_DRAW   field        845
# 102498     102495                          VIEW_LOG_TAG   field        850
# 102499     102495                      AUTOFILL_LOG_TAG   field        857
# 102500     102495               CONTENT_CAPTURE_LOG_TAG   field        862
# ...           ...                                   ...     ...        ...
# 104116     102495     onVirtualViewTranslationResponses  method      31657
# 104117     102495  dispatchCreateViewTranslationRequest  method      31689
# 104118     102495        ViewTranslationRequestConsumer   class      31708
# 104119     102495                   generateDisplayHash  method      31748
# 104120     102495                 getRootSurfaceControl  method      31809
#
#         end_row
# id
# 102496      842
# 102497      845
# 102498      850
# 102499      857
# 102500      862
# ...         ...
# 104116    31660
# 104117    31706
# 104118    31732
# 104119    31798
# 104120    31814
#
# [1625 rows x 5 columns]

# %%
deps_df
# Out:
#       src_id  tgt_id kind
# 1     104029  103046  Use
# 19    104036  103046  Use
# 21    104037  103046  Use
# 23    104038  103046  Use
# 25    104039  103046  Use
# ...      ...     ...  ...
# 4021  103336  102594  Use
# 4022  103336  102899  Use
# 4023  103334  102578  Use
# 4024  103334  102579  Use
# 4025  103334  102899  Use
#
# [3813 rows x 3 columns]

# %%
M = create_sym_mat(len(entities_df), deps_df)
D = np.diag(np.sum(M, axis=0))
L = D - M
L_inv = linalg.pinv(L, hermitian=True)

# %%
arb_id = 430
entities_df.iloc[arb_id]
# Out:
# parent_id               102495
# name         mUserPaddingStart
# kind                     field
# start_row                 4554
# end_row                   4555
# Name: 102926, dtype: object

# %%
df = entities_df.copy()
df["sim"] = L_inv[arb_id]
df.sort_values(by="sim", ascending=False).head(15)
# Out:
#         parent_id                          name    kind  start_row  end_row  \
# id
# 102926     102495             mUserPaddingStart   field       4554     4555
# 103880     102495             isPaddingRelative  method      25366    25368
# 103265     102495                   applyInsets  method      11523    11529
# 103870     102495                    setPadding  method      25148    25161
# 103882     102495   resetPaddingToInitialValues  method      25377    25391
# 103872     102495            setPaddingRelative  method      25242    25262
# 102930     102495             UNDEFINED_PADDING   field       4583     4583
# 102927     102495               mUserPaddingEnd   field       4561     4562
# 102929     102495      mUserPaddingRightInitial   field       4578     4578
# 102928     102495       mUserPaddingLeftInitial   field       4570     4570
# 102931     102495           mLeftPaddingDefined   field       4589     4589
# 102932     102495          mRightPaddingDefined   field       4595     4595
# 103732     102495  resetResolvedPaddingInternal  method      21105    21107
# 103730     102495                resolvePadding  method      21032    21089
# 102719     102495          LAYOUT_DIRECTION_LTR   field       2726     2726
#
#              sim
# id
# 102926  0.132870
# 103880  0.059107
# 103265  0.029944
# 103870  0.029268
# 103882  0.028022
# 103872  0.024029
# 102930  0.023391
# 102927  0.021759
# 102929  0.018601
# 102928  0.018601
# 102931  0.014448
# 102932  0.014448
# 103732  0.012801
# 103730  0.012107
# 102719  0.011242

# %%
L_inv[0]
# Out:
# array([ 2.53825870e-01, -1.82150322e-04,  6.09640055e-04, ...,
#        -5.24684254e-03,  3.65990279e-04,  9.71607622e-04])
